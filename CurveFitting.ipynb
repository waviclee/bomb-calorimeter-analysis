# %%
# %run curve_fitting_colab.py
# Out:
# 'data/sample_data.csv' not found, created a sample file.
# ...
#    EXPONENTIAL COOLING FIT vs LINEAR FIT COMPARISON
# ...
#
# [Pre-Period]
#   T_inf = 43.4385 +/- 13700.3502 C
#   A     = -18.3375 +/- 13700.3503 C
#   k     = 0.000008 +/- 0.005764 1/s
#   R^2 (exponential) = 0.994744
#   R^2 (linear)      = 0.994749
#   -> Linear approximation is adequate for this phase.
#
# [Post-Period]
#   T_inf = 26.6991 +/- 0.3270 C
#   A     = 0.7588 +/- 0.3269 C
#   k     = 0.000963 +/- 0.000433 1/s
#   R^2 (exponential) = 0.999790
#   R^2 (linear)      = 0.999642
#   -> Exponential model fits meaningfully better than linear.
#
# ...
# Instantaneous drift rate examples:
#   [Pre-Period] dT/dt at t=0s: 0.000141 C/s | at t=50s: 0.000141 C/s | (constant linear rate: 0.000141 C/s)
#   [Post-Period] dT/dt at t=210s: -0.000731 C/s | at t=300s: -0.000670 C/s | (constant linear rate: -0.000700 C/s)
